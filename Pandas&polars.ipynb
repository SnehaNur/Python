# %%
import pandas as pd
path ="https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD"

# %%
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year    Make  \
# 0  2T3YL4DV0E      King  Bellevue    WA      98005.0        2014  TOYOTA
# 1  5YJ3E1EB6K      King   Bothell    WA      98011.0        2019   TESLA
# 2  5UX43EU02S  Thurston   Olympia    WA      98502.0        2025     BMW
# 3  JTMAB3FV5R  Thurston   Olympia    WA      98513.0        2024  TOYOTA
# 4  5YJYGDEE8M    Yakima     Selah    WA      98942.0        2021   TESLA
#
#         Model                   Electric Vehicle Type  \
# 0        RAV4          Battery Electric Vehicle (BEV)
# 1     MODEL 3          Battery Electric Vehicle (BEV)
# 2          X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 4     MODEL Y          Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible           103.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232230 entries, 0 to 232229
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         232230 non-null  object
#  1   County                                             232226 non-null  object
#  2   City                                               232226 non-null  object
#  3   State                                              232230 non-null  object
#  4   Postal Code                                        232226 non-null  float64
#  5   Model Year                                         232230 non-null  int64
#  6   Make                                               232230 non-null  object
#  7   Model                                              232230 non-null  object
# ...

# %%
data.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  232226.000000  232230.000000   232203.000000  232203.000000
# mean    98180.172044    2021.353727       46.755998     803.808973
# std      2489.407943       2.994884       84.373596    7246.597102
# min      1731.000000    1999.000000        0.000000       0.000000
# 25%     98052.000000    2020.000000        0.000000       0.000000
# 50%     98126.000000    2023.000000        0.000000       0.000000
# 75%     98375.000000    2023.000000       38.000000       0.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         231749.000000    2.322300e+05       2.322260e+05
# mean              28.880979    2.343671e+08       5.298177e+10
# std               14.904503    6.831418e+07       1.507814e+09
# min                1.000000    4.385000e+03       1.001020e+09
# ...

# %%
data["Legislative District"][:10]
# Out:
# 0    41.0
# 1     1.0
# 2    35.0
# 3     2.0
# 4    15.0
# 5    22.0
# 6    39.0
# 7    43.0
# 8     2.0
# 9     2.0
# Name: Legislative District, dtype: float64

# %%
data.isnull()
# Out:
#         VIN (1-10)  County   City  State  Postal Code  Model Year   Make  \
# 0            False   False  False  False        False       False  False
# 1            False   False  False  False        False       False  False
# 2            False   False  False  False        False       False  False
# 3            False   False  False  False        False       False  False
# 4            False   False  False  False        False       False  False
# ...            ...     ...    ...    ...          ...         ...    ...
# 232225       False   False  False  False        False       False  False
# 232226       False   False  False  False        False       False  False
# 232227       False   False  False  False        False       False  False
# 232228       False   False  False  False        False       False  False
# 232229       False   False  False  False        False       False  False
#
#         Model  Electric Vehicle Type  \
# 0       False                  False
# ...

# %%
data.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                        27
# Base MSRP                                             27
# Legislative District                                 481
# DOL Vehicle ID                                         0
# Vehicle Location                                      11
# Electric Utility                                       4
# ...

# %%
data.isnull().mean(axis=0)
# Out:
# VIN (1-10)                                           0.000000
# County                                               0.000017
# City                                                 0.000017
# State                                                0.000000
# Postal Code                                          0.000017
# Model Year                                           0.000000
# Make                                                 0.000000
# Model                                                0.000000
# Electric Vehicle Type                                0.000000
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.000000
# Electric Range                                       0.000116
# Base MSRP                                            0.000116
# Legislative District                                 0.000000
# DOL Vehicle ID                                       0.000000
# Vehicle Location                                     0.000047
# ...

# %%
data['Legislative District'] = data['Legislative District'].map(lambda x: x * 1.1)

# %%
data
# Out:
#         VIN (1-10)     County         City State  Postal Code  Model Year  \
# 0       2T3YL4DV0E       King     Bellevue    WA      98005.0        2014
# 1       5YJ3E1EB6K       King      Bothell    WA      98011.0        2019
# 2       5UX43EU02S   Thurston      Olympia    WA      98502.0        2025
# 3       JTMAB3FV5R   Thurston      Olympia    WA      98513.0        2024
# 4       5YJYGDEE8M     Yakima        Selah    WA      98942.0        2021
# ...            ...        ...          ...   ...          ...         ...
# 232225  5YJ3E1EA3K       King       Renton    WA      98058.0        2019
# 232226  1GKB0RDC1R  Snohomish    Snohomish    WA      98290.0        2024
# 232227  7SAYGDED3R       King      Redmond    WA      98033.0        2024
# 232228  JTMEB3FV5P     Chelan  Leavenworth    WA      98826.0        2023
# 232229  5YJYGDEE3M     Kitsap    Bremerton    WA      98312.0        2021
#
#           Make          Model                   Electric Vehicle Type  \
# ...

# %%
data['Electric Range'].mean()
# Out:
# 46.75599798452216

# %%
data['Electric Range'] = data['Electric Range'].fillna(data['Electric Range'].mean())

# %%
data['Electric Range']
# Out:
# 0         103.0
# 1         220.0
# 2          40.0
# 3          42.0
# 4           0.0
#           ...
# 232225    220.0
# 232226      0.0
# 232227      0.0
# 232228     42.0
# 232229      0.0
# Name: Electric Range, Length: 232230, dtype: float64

# %%
data.plot(kind='bar', x='Model Year', y='Electric Range')
